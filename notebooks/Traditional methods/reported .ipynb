# %%
import pickle

# %%
import os

name_smt = []
confs_smt = []
resutl_smt= []

#extract names
names_smt_path = 'smt/names'
for root, dirs, files in os.walk(names_smt_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        name_smt.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
        
#extract confs
confs_smt_path = 'smt/confs'
for root, dirs, files in os.walk(confs_smt_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        confs_smt.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
        
        
#extract result
result_smt_path = 'smt/result'
for root, dirs, files in os.walk(result_smt_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        resutl_smt.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
# Out:
# smt/names/names_smotev1.pkl
# --------done---------
# smt/names/names_smotev2.pkl
# --------done---------
# smt/confs/confs_smotev1.pkl
# --------done---------
# smt/confs/confs_smotev2.pkl
# --------done---------
# smt/result/results_smotev1.pkl
# --------done---------
# smt/result/results_smotev2.pkl
# --------done---------

# %%
name_smt
# Out:
# [['10trees_10leafSamples_sqrtmaxFeat',
#   '10trees_10leafSamples_log2maxFeat',
#   '10trees_10leafSamples_NonemaxFeat',
#   '10trees_50leafSamples_sqrtmaxFeat',
#   '10trees_50leafSamples_log2maxFeat',
#   '10trees_50leafSamples_NonemaxFeat',
#   '50trees_10leafSamples_sqrtmaxFeat',
#   '50trees_10leafSamples_log2maxFeat',
#   '50trees_10leafSamples_NonemaxFeat',
#   '50trees_50leafSamples_sqrtmaxFeat',
#   '50trees_50leafSamples_log2maxFeat',
#   '50trees_50leafSamples_NonemaxFeat',
#   '100trees_10leafSamples_sqrtmaxFeat',
#   '100trees_10leafSamples_log2maxFeat',
#   '100trees_10leafSamples_NonemaxFeat',
#   '100trees_50leafSamples_sqrtmaxFeat',
#   '100trees_50leafSamples_log2maxFeat',
#   '100trees_50leafSamples_NonemaxFeat',
#   '200trees_10leafSamples_sqrtmaxFeat',
#   '200trees_10leafSamples_log2maxFeat',
#   '200trees_10leafSamples_NonemaxFeat',
#   '200trees_50leafSamples_sqrtmaxFeat',
#   '200trees_50leafSamples_log2maxFeat',
#   '200trees_50leafSamples_NonemaxFeat'],
#  ['10trees_100leafSamples_sqrtmaxFeat',
#   '10trees_100leafSamples_log2maxFeat',
#   '10trees_100leafSamples_NonemaxFeat',
#   '10trees_500leafSamples_sqrtmaxFeat',
#   '10trees_500leafSamples_log2maxFeat',
#   '10trees_500leafSamples_NonemaxFeat',
#   '10trees_1000leafSamples_sqrtmaxFeat',
#   '10trees_1000leafSamples_log2maxFeat',
#   '10trees_1000leafSamples_NonemaxFeat',
#   '10trees_5000leafSamples_sqrtmaxFeat',
#   '10trees_5000leafSamples_log2maxFeat',
#   '10trees_5000leafSamples_NonemaxFeat',
#   '50trees_100leafSamples_sqrtmaxFeat',
#   '50trees_100leafSamples_log2maxFeat',
#   '50trees_100leafSamples_NonemaxFeat',
#   '50trees_500leafSamples_sqrtmaxFeat',
#   '50trees_500leafSamples_log2maxFeat',
#   '50trees_500leafSamples_NonemaxFeat',
#   '50trees_1000leafSamples_sqrtmaxFeat',
#   '50trees_1000leafSamples_log2maxFeat',
#   '50trees_1000leafSamples_NonemaxFeat',
#   '50trees_5000leafSamples_sqrtmaxFeat',
#   '50trees_5000leafSamples_log2maxFeat',
#   '50trees_5000leafSamples_NonemaxFeat',
#   '100trees_100leafSamples_sqrtmaxFeat',
#   '100trees_100leafSamples_log2maxFeat',
#   '100trees_100leafSamples_NonemaxFeat',
#   '100trees_500leafSamples_sqrtmaxFeat',
#   '100trees_500leafSamples_log2maxFeat',
#   '100trees_500leafSamples_NonemaxFeat',
#   '100trees_1000leafSamples_sqrtmaxFeat',
#   '100trees_1000leafSamples_log2maxFeat',
#   '100trees_1000leafSamples_NonemaxFeat',
#   '100trees_5000leafSamples_sqrtmaxFeat',
#   '100trees_5000leafSamples_log2maxFeat',
#   '100trees_5000leafSamples_NonemaxFeat',
#   '200trees_100leafSamples_sqrtmaxFeat',
#   '200trees_100leafSamples_log2maxFeat',
#   '200trees_100leafSamples_NonemaxFeat',
#   '200trees_500leafSamples_sqrtmaxFeat',
#   '200trees_500leafSamples_log2maxFeat',
#   '200trees_500leafSamples_NonemaxFeat',
#   '200trees_1000leafSamples_sqrtmaxFeat',
#   '200trees_1000leafSamples_log2maxFeat',
#   '200trees_1000leafSamples_NonemaxFeat',
#   '200trees_5000leafSamples_sqrtmaxFeat',
#   '200trees_5000leafSamples_log2maxFeat',
#   '200trees_5000leafSamples_NonemaxFeat']]

# %%
confs_smt
# Out:
# [[array([[667766,  19397],
#          [   263,    976]]),
#   array([[673248,  13915],
#          [   302,    937]]),
#   array([[677688,   9475],
#          [   372,    867]]),
#   array([[649817,  37346],
#          [   165,   1074]]),
#   array([[658816,  28347],
#          [   198,   1041]]),
#   array([[665256,  21907],
#          [   213,   1026]]),
#   array([[668998,  18165],
#          [   245,    994]]),
#   array([[675040,  12123],
#          [   297,    942]]),
#   array([[678566,   8597],
#          [   355,    884]]),
#   array([[651509,  35654],
#          [   161,   1078]]),
#   array([[660672,  26491],
#          [   188,   1051]]),
#   array([[666901,  20262],
#          [   221,   1018]]),
#   array([[669636,  17527],
#          [   253,    986]]),
#   array([[675087,  12076],
#          [   302,    937]]),
#   array([[678681,   8482],
#          [   361,    878]]),
#   array([[652724,  34439],
#          [   168,   1071]]),
#   array([[660867,  26296],
#          [   177,   1062]]),
#   array([[667162,  20001],
#          [   227,   1012]]),
#   array([[669992,  17171],
#          [   248,    991]]),
#   array([[675267,  11896],
#          [   297,    942]]),
#   array([[678779,   8384],
#          [   355,    884]]),
#   array([[652451,  34712],
#          [   156,   1083]]),
#   array([[660947,  26216],
#          [   188,   1051]]),
#   array([[667349,  19814],
#          [   226,   1013]])],
#  [array([[639823,  47340],
#          [   158,   1081]]),
#   array([[651804,  35359],
#          [   167,   1072]]),
#   array([[659145,  28018],
#          [   186,   1053]]),
#   array([[615886,  71277],
#          [   138,   1101]]),
#   array([[636058,  51105],
#          [   132,   1107]]),
#   array([[641395,  45768],
#          [   129,   1110]]),
#   array([[606577,  80586],
#          [   129,   1110]]),
#   array([[625249,  61914],
#          [   142,   1097]]),
#   array([[635001,  52162],
#          [   121,   1118]]),
#   array([[612170,  74993],
#          [   168,   1071]]),
#   array([[614938,  72225],
#          [   155,   1084]]),
#   array([[625190,  61973],
#          [   136,   1103]]),
#   array([[644062,  43101],
#          [   146,   1093]]),
#   array([[653956,  33207],
#          [   158,   1081]]),
#   array([[660705,  26458],
#          [   177,   1062]]),
#   array([[626887,  60276],
#          [   139,   1100]]),
#   array([[637127,  50036],
#          [   136,   1103]]),
#   array([[643239,  43924],
#          [   125,   1114]]),
#   array([[623945,  63218],
#          [   149,   1090]]),
#   array([[630552,  56611],
#          [   130,   1109]]),
#   array([[637277,  49886],
#          [   122,   1117]]),
#   array([[617753,  69410],
#          [   150,   1089]]),
#   array([[618368,  68795],
#          [   140,   1099]]),
#   array([[624692,  62471],
#          [   125,   1114]]),
#   array([[643917,  43246],
#          [   148,   1091]]),
#   array([[653433,  33730],
#          [   155,   1084]]),
#   array([[660630,  26533],
#          [   177,   1062]]),
#   array([[626162,  61001],
#          [   141,   1098]]),
#   array([[636278,  50885],
#          [   131,   1108]]),
#   array([[643999,  43164],
#          [   129,   1110]]),
#   array([[621092,  66071],
#          [   144,   1095]]),
#   array([[631939,  55224],
#          [   133,   1106]]),
#   array([[637543,  49620],
#          [   124,   1115]]),
#   array([[604893,  82270],
#          [   153,   1086]]),
#   array([[620658,  66505],
#          [   141,   1098]]),
#   array([[625172,  61991],
#          [   124,   1115]]),
#   array([[643873,  43290],
#          [   147,   1092]]),
#   array([[653748,  33415],
#          [   155,   1084]]),
#   array([[660698,  26465],
#          [   182,   1057]]),
#   array([[626521,  60642],
#          [   139,   1100]]),
#   array([[637696,  49467],
#          [   132,   1107]]),
#   array([[644016,  43147],
#          [   127,   1112]]),
#   array([[620798,  66365],
#          [   137,   1102]]),
#   array([[631846,  55317],
#          [   128,   1111]]),
#   array([[637577,  49586],
#          [   122,   1117]]),
#   array([[606559,  80604],
#          [   154,   1085]]),
#   array([[618121,  69042],
#          [   138,   1101]]),
#   array([[626072,  61091],
#          [   125,   1114]])]]

# %%
resutl_smt
# Out:
# [[0.12517950947317197,
#   0.07898740686076273,
#   0.05417888242864439,
#   0.20048053072958888,
#   0.14503039900359954,
#   0.09990107814833901,
#   0.1281329862666528,
#   0.07484126777854219,
#   0.04919398717317853,
#   0.19998286898900472,
#   0.1381170141951318,
#   0.09626501388756976,
#   0.12428162416139728,
#   0.07655059782007266,
#   0.04842666356802996,
#   0.19713416002814851,
#   0.1382638345133045,
#   0.09593690460183638,
#   0.12177355954055255,
#   0.07514649966917547,
#   0.04822481714661964,
#   0.19888597319900278,
#   0.13835450444857725,
#   0.09568208992796168],
#  [0.23847257850405768,
#   0.17136794669106858,
#   0.12326196094041897,
#   0.3036266889192871,
#   0.24673058849654153,
#   0.18542738618415328,
#   0.3292985128488076,
#   0.25774173109914644,
#   0.20807390983707244,
#   0.3613630076806684,
#   0.3259891016865443,
#   0.25450978259594065,
#   0.23981301638002495,
#   0.16571987039950428,
#   0.12065538482747978,
#   0.28773939748365907,
#   0.23350161397249058,
#   0.1821071186161241,
#   0.3272771006762833,
#   0.25725557261126103,
#   0.20422628359130787,
#   0.3883584644404014,
#   0.31035561530674,
#   0.2526089224889234,
#   0.23029466972180418,
#   0.17108172942422462,
#   0.12118968225409874,
#   0.3054292764305727,
#   0.2286796760665534,
#   0.18109559877363704,
#   0.3226775445034026,
#   0.2556920399711948,
#   0.203914202814477,
#   0.3856519580387136,
#   0.30537762068403285,
#   0.2506309523808099,
#   0.23383994555197443,
#   0.16670408348941868,
#   0.12084997737428309,
#   0.3022558287955334,
#   0.23079395684493,
#   0.18116982799295647,
#   0.3212058389423185,
#   0.25565685362135654,
#   0.20406501998828042,
#   0.3977916243898117,
#   0.31262316971778115,
#   0.250181798543296]]

# %%
for items in name_smt[0]:
    print(items)
    print("ssss")
# Out:
# 10trees_10leafSamples_sqrtmaxFeat
# ssss
# 10trees_10leafSamples_log2maxFeat
# ssss
# 10trees_10leafSamples_NonemaxFeat
# ssss
# 10trees_50leafSamples_sqrtmaxFeat
# ssss
# 10trees_50leafSamples_log2maxFeat
# ssss
# 10trees_50leafSamples_NonemaxFeat
# ssss
# 50trees_10leafSamples_sqrtmaxFeat
# ssss
# 50trees_10leafSamples_log2maxFeat
# ssss
# 50trees_10leafSamples_NonemaxFeat
# ssss
# 50trees_50leafSamples_sqrtmaxFeat
# ssss
# 50trees_50leafSamples_log2maxFeat
# ssss
# 50trees_50leafSamples_NonemaxFeat
# ssss
# 100trees_10leafSamples_sqrtmaxFeat
# ssss
# 100trees_10leafSamples_log2maxFeat
# ssss
# 100trees_10leafSamples_NonemaxFeat
# ssss
# 100trees_50leafSamples_sqrtmaxFeat
# ssss
# 100trees_50leafSamples_log2maxFeat
# ssss
# 100trees_50leafSamples_NonemaxFeat
# ssss
# 200trees_10leafSamples_sqrtmaxFeat
# ssss
# 200trees_10leafSamples_log2maxFeat
# ssss
# 200trees_10leafSamples_NonemaxFeat
# ssss
# 200trees_50leafSamples_sqrtmaxFeat
# ssss
# 200trees_50leafSamples_log2maxFeat
# ssss
# 200trees_50leafSamples_NonemaxFeat
# ssss

# %%
import os

name_clw = []
confs_clw = []
resutl_clw= []

#extract names
names_clw_path = 'clw/names'
for root, dirs, files in os.walk(names_clw_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        name_clw.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
        
#extract confs
confs_clw_path = 'clw/confs'
for root, dirs, files in os.walk(confs_clw_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        confs_clw.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
        
        
#extract result
result_clw_path = 'clw/result'
for root, dirs, files in os.walk(result_clw_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        resutl_clw.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
# Out:
# clw/names/names_class_weight_balanced_subsample.pkl
# --------done---------
# clw/confs/confs_class_weight_balanced_subsample.pkl
# --------done---------
# clw/result/results_class_weight_balanced_subsample.pkl
# --------done---------

# %%
name_clw
# Out:
# [['10trees_10leafSamples_sqrtmaxFeat',
#   '10trees_10leafSamples_log2maxFeat',
#   '10trees_10leafSamples_NonemaxFeat',
#   '10trees_50leafSamples_sqrtmaxFeat',
#   '10trees_50leafSamples_log2maxFeat',
#   '10trees_50leafSamples_NonemaxFeat',
#   '10trees_100leafSamples_sqrtmaxFeat',
#   '10trees_100leafSamples_log2maxFeat',
#   '10trees_100leafSamples_NonemaxFeat',
#   '10trees_500leafSamples_sqrtmaxFeat',
#   '10trees_500leafSamples_log2maxFeat',
#   '10trees_500leafSamples_NonemaxFeat',
#   '10trees_1000leafSamples_sqrtmaxFeat',
#   '10trees_1000leafSamples_log2maxFeat',
#   '10trees_1000leafSamples_NonemaxFeat',
#   '10trees_5000leafSamples_sqrtmaxFeat',
#   '10trees_5000leafSamples_log2maxFeat',
#   '10trees_5000leafSamples_NonemaxFeat',
#   '50trees_10leafSamples_sqrtmaxFeat',
#   '50trees_10leafSamples_log2maxFeat',
#   '50trees_10leafSamples_NonemaxFeat',
#   '50trees_50leafSamples_sqrtmaxFeat',
#   '50trees_50leafSamples_log2maxFeat',
#   '50trees_50leafSamples_NonemaxFeat',
#   '50trees_100leafSamples_sqrtmaxFeat',
#   '50trees_100leafSamples_log2maxFeat',
#   '50trees_100leafSamples_NonemaxFeat',
#   '50trees_500leafSamples_sqrtmaxFeat',
#   '50trees_500leafSamples_log2maxFeat',
#   '50trees_500leafSamples_NonemaxFeat',
#   '50trees_1000leafSamples_sqrtmaxFeat',
#   '50trees_1000leafSamples_log2maxFeat',
#   '50trees_1000leafSamples_NonemaxFeat',
#   '50trees_5000leafSamples_sqrtmaxFeat',
#   '50trees_5000leafSamples_log2maxFeat',
#   '50trees_5000leafSamples_NonemaxFeat',
#   '100trees_10leafSamples_sqrtmaxFeat',
#   '100trees_10leafSamples_log2maxFeat',
#   '100trees_10leafSamples_NonemaxFeat',
#   '100trees_50leafSamples_sqrtmaxFeat',
#   '100trees_50leafSamples_log2maxFeat',
#   '100trees_50leafSamples_NonemaxFeat',
#   '100trees_100leafSamples_sqrtmaxFeat',
#   '100trees_100leafSamples_log2maxFeat',
#   '100trees_100leafSamples_NonemaxFeat',
#   '100trees_500leafSamples_sqrtmaxFeat',
#   '100trees_500leafSamples_log2maxFeat',
#   '100trees_500leafSamples_NonemaxFeat',
#   '100trees_1000leafSamples_sqrtmaxFeat',
#   '100trees_1000leafSamples_log2maxFeat',
#   '100trees_1000leafSamples_NonemaxFeat',
#   '100trees_5000leafSamples_sqrtmaxFeat',
#   '100trees_5000leafSamples_log2maxFeat',
#   '100trees_5000leafSamples_NonemaxFeat',
#   '200trees_10leafSamples_sqrtmaxFeat',
#   '200trees_10leafSamples_log2maxFeat',
#   '200trees_10leafSamples_NonemaxFeat',
#   '200trees_50leafSamples_sqrtmaxFeat',
#   '200trees_50leafSamples_log2maxFeat',
#   '200trees_50leafSamples_NonemaxFeat',
#   '200trees_100leafSamples_sqrtmaxFeat',
#   '200trees_100leafSamples_log2maxFeat',
#   '200trees_100leafSamples_NonemaxFeat',
#   '200trees_500leafSamples_sqrtmaxFeat',
#   '200trees_500leafSamples_log2maxFeat',
#   '200trees_500leafSamples_NonemaxFeat',
#   '200trees_1000leafSamples_sqrtmaxFeat',
#   '200trees_1000leafSamples_log2maxFeat',
#   '200trees_1000leafSamples_NonemaxFeat',
#   '200trees_5000leafSamples_sqrtmaxFeat',
#   '200trees_5000leafSamples_log2maxFeat',
#   '200trees_5000leafSamples_NonemaxFeat']]

# %%
len(name_clw[0])
# Out:
# 72

# %%
confs_clw
# Out:
# [[array([[674906,  12257],
#          [   355,    884]]),
#   array([[681987,   5176],
#          [   433,    806]]),
#   array([[684510,   2653],
#          [   569,    670]]),
#   array([[642108,  45055],
#          [   168,   1071]]),
#   array([[663553,  23610],
#          [   228,   1011]]),
#   array([[672847,  14316],
#          [   285,    954]]),
#   array([[632291,  54872],
#          [   162,   1077]]),
#   array([[647009,  40154],
#          [   154,   1085]]),
#   array([[663363,  23800],
#          [   216,   1023]]),
#   array([[600237,  86926],
#          [   140,   1099]]),
#   array([[620672,  66491],
#          [   127,   1112]]),
#   array([[632652,  54511],
#          [   134,   1105]]),
#   array([[544400, 142763],
#          [   103,   1136]]),
#   array([[615216,  71947],
#          [   138,   1101]]),
#   array([[623763,  63400],
#          [   117,   1122]]),
#   array([[570681, 116482],
#          [   174,   1065]]),
#   array([[585650, 101513],
#          [   150,   1089]]),
#   array([[602357,  84806],
#          [   133,   1106]]),
#   array([[678118,   9045],
#          [   337,    902]]),
#   array([[682427,   4736],
#          [   430,    809]]),
#   array([[684484,   2679],
#          [   533,    706]]),
#   array([[649682,  37481],
#          [   181,   1058]]),
#   array([[665554,  21609],
#          [   226,   1013]]),
#   array([[674250,  12913],
#          [   277,    962]]),
#   array([[636604,  50559],
#          [   145,   1094]]),
#   array([[652445,  34718],
#          [   166,   1073]]),
#   array([[665737,  21426],
#          [   199,   1040]]),
#   array([[617843,  69320],
#          [   145,   1094]]),
#   array([[624213,  62950],
#          [   126,   1113]]),
#   array([[636510,  50653],
#          [   122,   1117]]),
#   array([[597013,  90150],
#          [   138,   1101]]),
#   array([[604684,  82479],
#          [   117,   1122]]),
#   array([[624304,  62859],
#          [   119,   1120]]),
#   array([[579428, 107735],
#          [   136,   1103]]),
#   array([[592527,  94636],
#          [   146,   1093]]),
#   array([[604957,  82206],
#          [   136,   1103]]),
#   array([[677819,   9344],
#          [   349,    890]]),
#   array([[682560,   4603],
#          [   426,    813]]),
#   array([[684480,   2683],
#          [   529,    710]]),
#   array([[648369,  38794],
#          [   178,   1061]]),
#   array([[665804,  21359],
#          [   220,   1019]]),
#   array([[674336,  12827],
#          [   281,    958]]),
#   array([[631533,  55630],
#          [   151,   1088]]),
#   array([[653890,  33273],
#          [   168,   1071]]),
#   array([[665678,  21485],
#          [   204,   1035]]),
#   array([[603824,  83339],
#          [   134,   1105]]),
#   array([[622401,  64762],
#          [   126,   1113]]),
#   array([[637384,  49779],
#          [   127,   1112]]),
#   array([[594099,  93064],
#          [   146,   1093]]),
#   array([[614458,  72705],
#          [   125,   1114]]),
#   array([[624842,  62321],
#          [   116,   1123]]),
#   array([[577943, 109220],
#          [   144,   1095]]),
#   array([[587621,  99542],
#          [   136,   1103]]),
#   array([[605260,  81903],
#          [   129,   1110]]),
#   array([[678040,   9123],
#          [   341,    898]]),
#   array([[682525,   4638],
#          [   418,    821]]),
#   array([[684501,   2662],
#          [   525,    714]]),
#   array([[650492,  36671],
#          [   170,   1069]]),
#   array([[666110,  21053],
#          [   221,   1018]]),
#   array([[674547,  12616],
#          [   278,    961]]),
#   array([[633950,  53213],
#          [   144,   1095]]),
#   array([[654199,  32964],
#          [   168,   1071]]),
#   array([[665881,  21282],
#          [   205,   1034]]),
#   array([[604619,  82544],
#          [   128,   1111]]),
#   array([[622547,  64616],
#          [   123,   1116]]),
#   array([[637161,  50002],
#          [   122,   1117]]),
#   array([[599264,  87899],
#          [   139,   1100]]),
#   array([[610124,  77039],
#          [   121,   1118]]),
#   array([[625922,  61241],
#          [   117,   1122]]),
#   array([[585507, 101656],
#          [   156,   1083]]),
#   array([[593305,  93858],
#          [   131,   1108]]),
#   array([[604582,  82581],
#          [   125,   1114]])]]

# %%
resutl_clw
# Out:
# [[0.17668691762334074,
#   0.04441907296174074,
#   0.02836856561565391,
#   0.24011479738837146,
#   0.12230810863352273,
#   0.0730630025178162,
#   0.27275869061466557,
#   0.1755915394983763,
#   0.10701816787856379,
#   0.3538117457017267,
#   0.2679219156942424,
#   0.20557471499909286,
#   0.4754470165492225,
#   0.30656429237938837,
#   0.23828896864867183,
#   0.49182118418844273,
#   0.367681727882914,
#   0.3087249871163486,
#   0.09823182386467055,
#   0.0390087167566164,
#   0.022400978622688583,
#   0.2169516515339041,
#   0.12054332538437904,
#   0.06672754729745867,
#   0.2769596776889936,
#   0.18818403457598268,
#   0.10084011961004252,
#   0.3937450196323708,
#   0.27846342065203045,
#   0.2006572160629446,
#   0.4084209256570005,
#   0.3276730371989069,
#   0.23769430160757696,
#   0.4593199384428793,
#   0.37445244349213735,
#   0.30645293579977523,
#   0.10431471324890074,
#   0.03866461497351935,
#   0.02127632464102462,
#   0.24730213069816456,
#   0.12463091412917768,
#   0.0658959891729573,
#   0.28928176210525114,
#   0.1727157798005421,
#   0.10038149021421794,
#   0.3831640063078568,
#   0.2782267020004666,
#   0.19833467236295782,
#   0.4028315860158224,
#   0.31439082281701336,
#   0.23717073548495984,
#   0.45392961869909476,
#   0.3842962482378039,
#   0.30287936225288103,
#   0.10177939250403553,
#   0.03929508295703181,
#   0.020838980808802997,
#   0.22807798733698384,
#   0.12179555078825474,
#   0.06505028195984269,
#   0.288379968733556,
#   0.17094574176690155,
#   0.10015357979205912,
#   0.37497131887990215,
#   0.2816414713957446,
#   0.19894517400812797,
#   0.4100207107803694,
#   0.3180754517282323,
#   0.23581083388764953,
#   0.45583211349574815,
#   0.37643865660801173,
#   0.3045812666136291]]

# %%
name_ada = []
confs_ada = []
resutl_ada= []

#extract names
names_adaboost_path = 'adaboost/names'
for root, dirs, files in os.walk(names_adaboost_path, topdown=False):
    files = sorted(files)
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        name_ada.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
        
#extract confs
confs_adaboost_path = 'adaboost/confs'
for root, dirs, files in os.walk(confs_adaboost_path, topdown=False):
    files = sorted(files)
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        confs_ada.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
        
        
#extract result
result_adaboost_path = 'adaboost/result'
for root, dirs, files in os.walk(result_adaboost_path, topdown=False):
    files = sorted(files)
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        resutl_ada.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
# Out:
# adaboost/names/names_adabost_smote_v1.pkl
# --------done---------
# adaboost/names/names_adabost_smote_v2.pkl
# --------done---------
# adaboost/names/names_adabost_smote_v3.pkl
# --------done---------
# adaboost/names/names_adabost_smote_v4.pkl
# --------done---------
# adaboost/names/names_adabost_smote_v5.pkl
# --------done---------
# adaboost/names/names_adabost_smote_v6.pkl
# --------done---------
# adaboost/confs/confs_adabost_smote_v1.pkl
# --------done---------
# adaboost/confs/confs_adabost_smote_v2.pkl
# --------done---------
# adaboost/confs/confs_adabost_smote_v3.pkl
# --------done---------
# adaboost/confs/confs_adabost_smote_v4.pkl
# --------done---------
# adaboost/confs/confs_adabost_smote_v5.pkl
# --------done---------
# adaboost/confs/confs_adabost_smote_v6.pkl
# --------done---------
# adaboost/result/results_adabost_smote_v1.pkl
# --------done---------
# adaboost/result/results_adabost_smote_v2.pkl
# --------done---------
# adaboost/result/results_adabost_smote_v3.pkl
# --------done---------
# adaboost/result/results_adabost_smote_v4.pkl
# --------done---------
# adaboost/result/results_adabost_smote_v5.pkl
# --------done---------
# adaboost/result/results_adabost_smote_v6.pkl
# --------done---------

# %%
name_ada
# Out:
# [['10trees_0.001learning_rate',
#   '50trees_0.001learning_rate',
#   '100trees_0.001learning_rate',
#   '200trees_0.001learning_rate'],
#  ['10trees_0.01learning_rate',
#   '50trees_0.01learning_rate',
#   '100trees_0.01learning_rate',
#   '200trees_0.01learning_rate'],
#  ['10trees_0.1learning_rate',
#   '50trees_0.1learning_rate',
#   '100trees_0.1learning_rate',
#   '200trees_0.1learning_rate'],
#  ['10trees_0.5learning_rate',
#   '50trees_0.5learning_rate',
#   '100trees_0.5learning_rate',
#   '200trees_0.5learning_rate'],
#  ['10trees_1.0learning_rate',
#   '50trees_1.0learning_rate',
#   '100trees_1.0learning_rate',
#   '200trees_1.0learning_rate'],
#  ['10trees_2.0learning_rate',
#   '50trees_2.0learning_rate',
#   '100trees_2.0learning_rate',
#   '200trees_2.0learning_rate']]

# %%
confs_ada
# Out:
# [[array([[538078, 149085],
#          [   223,   1016]]),
#   array([[538078, 149085],
#          [   223,   1016]]),
#   array([[538078, 149085],
#          [   223,   1016]]),
#   array([[538078, 149085],
#          [   223,   1016]])],
#  [array([[537969, 149194],
#          [   223,   1016]]),
#   array([[536346, 150817],
#          [   207,   1032]]),
#   array([[552970, 134193],
#          [   191,   1048]]),
#   array([[576790, 110373],
#          [   178,   1061]])],
#  [array([[563879, 123284],
#          [   220,   1019]]),
#   array([[601101,  86062],
#          [   161,   1078]]),
#   array([[616267,  70896],
#          [   137,   1102]]),
#   array([[616037,  71126],
#          [   124,   1115]])],
#  [array([[575467, 111696],
#          [   157,   1082]]),
#   array([[614860,  72303],
#          [   116,   1123]]),
#   array([[615814,  71349],
#          [   117,   1122]]),
#   array([[616836,  70327],
#          [   119,   1120]])],
#  [array([[592614,  94549],
#          [   190,   1049]]),
#   array([[613653,  73510],
#          [   132,   1107]]),
#   array([[616202,  70961],
#          [   131,   1108]]),
#   array([[617389,  69774],
#          [   128,   1111]])],
#  [array([[149088, 538075],
#          [  1016,    223]]),
#   array([[149088, 538075],
#          [  1016,    223]]),
#   array([[149078, 538085],
#          [  1016,    223]]),
#   array([[149047, 538116],
#          [  1016,    223]])]]

# %%
resutl_ada
# Out:
# [[0.5264386305068719,
#   0.5253956285302244,
#   0.5204709109886573,
#   0.5151657586604831],
#  [0.5198490166715198,
#   0.5057964941643428,
#   0.5145597664389053,
#   0.5390821927380259],
#  [0.5116140491581431,
#   0.5779618173048203,
#   0.610423497143533,
#   0.6365324578927869],
#  [0.5686747357938499,
#   0.642020659014213,
#   0.6518577150589563,
#   0.6712696791332491],
#  [0.5942694930520671,
#   0.662852974728991,
#   0.6709770447521094,
#   0.6781766979421067],
#  [0.693147082612924,
#   0.693147116490805,
#   0.6931471338744627,
#   0.6931471608951545]]

# %%
import os

name_clw_bal = []
confs_clw = []
resutl_clw= []

#extract names
names_clw_path = 'clw/names'
for root, dirs, files in os.walk(names_clw_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        name_clw.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
        
#extract confs
confs_clw_path = 'clw/confs'
for root, dirs, files in os.walk(confs_clw_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        confs_clw.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
        
        
#extract result
result_clw_path = 'clw/result'
for root, dirs, files in os.walk(result_clw_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        file_name = os.path.join(root, name)
        open_file = open(file_name, "rb")
        loaded_list_names = pickle.load(open_file)
        resutl_clw.append(loaded_list_names)
        open_file.close()
        print("--------done---------")
