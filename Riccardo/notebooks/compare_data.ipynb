# %%
import pandas as pd

# %%
data_path1 = "/home/b/b382633/TC_adds/csv_extracted/"
data_path2 = "/work/bk1318/b382633/data_csv/predictors_v2_dailymean/"

# %%
data_path1 = "/work/bk1318/b382633/csv_extracted_1/"
data_path2 = "/work/bk1318/b382633/data_csv/predictors_v2_dailymean_1/"

# %%
target_test = "target_test_dailymeans_Sindian.csv"
target_train = "target_train_dailymeans_Sindian.csv"
target_val = "target_val_dailymeans_Sindian.csv"
feature_test = "test_dailymeans_Sindian.csv"
feature_train = "train_dailymeans_Sindian.csv"
feature_val = "val_dailymeans_Sindian.csv"
current_file = feature_test

# %%
my_df = pd.read_csv(data_path1 + current_file)
my_df.shape
# Out:
# (5427666, 15)

# %%
my_df
# Out:
#          Unnamed: 0  latitude  longitude        time        vo          r  \
# 0                 0       0.0       20.0  2016-04-01  0.000003  82.689590
# 1                 1       0.0       21.0  2016-04-01  0.000011  87.146570
# 2                 2       0.0       22.0  2016-04-01 -0.000001  78.225174
# 3                 3       0.0       23.0  2016-04-01 -0.000003  71.998116
# 4                 4       0.0       24.0  2016-04-01  0.000009  75.876660
# ...             ...       ...        ...         ...       ...        ...
# 5427661     5427661     -30.0       86.0  2022-12-31 -0.000003   9.031833
# 5427662     5427662     -30.0       87.0  2022-12-31 -0.000011   8.893886
# 5427663     5427663     -30.0       88.0  2022-12-31 -0.000012   8.432330
# 5427664     5427664     -30.0       89.0  2022-12-31 -0.000004   7.901454
# 5427665     5427665     -30.0       90.0  2022-12-31  0.000001   7.244884
#
#              u_200     u_850      v_200     v_850        sst       tcwv  \
# ...

# %%
other_df = pd.read_csv(data_path2 + current_file)
other_df.shape
# Out:
# (5427666, 15)

# %%
other_df
# Out:
#          Unnamed: 0  latitude  longitude        time        vo          r  \
# 0                 0       0.0       20.0  2016-04-01  0.000003  82.689590
# 1                 1       0.0       21.0  2016-04-01  0.000011  87.146570
# 2                 2       0.0       22.0  2016-04-01 -0.000001  78.225174
# 3                 3       0.0       23.0  2016-04-01 -0.000003  71.998116
# 4                 4       0.0       24.0  2016-04-01  0.000009  75.876660
# ...             ...       ...        ...         ...       ...        ...
# 5427661     5427661     -30.0       86.0  2022-12-31 -0.000003   9.031833
# 5427662     5427662     -30.0       87.0  2022-12-31 -0.000011   8.893886
# 5427663     5427663     -30.0       88.0  2022-12-31 -0.000012   8.432330
# 5427664     5427664     -30.0       89.0  2022-12-31 -0.000004   7.901454
# 5427665     5427665     -30.0       90.0  2022-12-31  0.000001   7.244884
#
#              u_200     u_850      v_200     v_850        sst       tcwv  \
# ...

# %%
my_df.describe()
# Out:
#          Unnamed: 0      latitude     longitude            vo             r  \
# count  5.427666e+06  5.427666e+06  5.427666e+06  5.427666e+06  5.427666e+06
# mean   2.713832e+06 -1.500000e+01  5.500000e+01  1.634217e-07  4.513931e+01
# std    1.566832e+06  8.944273e+00  2.049390e+01  1.827597e-05  2.648397e+01
# min    0.000000e+00 -3.000000e+01  2.000000e+01 -8.602099e-04  5.407220e-02
# 25%    1.356916e+06 -2.300000e+01  3.700000e+01 -9.497104e-06  2.076227e+01
# 50%    2.713832e+06 -1.500000e+01  5.500000e+01  7.339986e-07  4.771658e+01
# 75%    4.070749e+06 -7.000000e+00  7.300000e+01  1.072703e-05  6.829339e+01
# max    5.427665e+06  0.000000e+00  9.000000e+01  2.337394e-04  1.015534e+02
#
#               u_200         u_850         v_200         v_850           sst  \
# count  5.427666e+06  5.427666e+06  5.427666e+06  5.427666e+06  5.427666e+06
# mean   7.656760e+00 -2.693753e+00 -1.856880e+00  9.688508e-01  2.177395e+02
# ...

# %%
other_df.describe()
# Out:
#          Unnamed: 0      latitude     longitude            vo             r  \
# count  5.427666e+06  5.427666e+06  5.427666e+06  5.427666e+06  5.427666e+06
# mean   2.713832e+06 -1.500000e+01  5.500000e+01  1.634217e-07  4.513931e+01
# std    1.566832e+06  8.944273e+00  2.049390e+01  1.827597e-05  2.648397e+01
# min    0.000000e+00 -3.000000e+01  2.000000e+01 -8.602099e-04  5.407220e-02
# 25%    1.356916e+06 -2.300000e+01  3.700000e+01 -9.497104e-06  2.076227e+01
# 50%    2.713832e+06 -1.500000e+01  5.500000e+01  7.339986e-07  4.771658e+01
# 75%    4.070749e+06 -7.000000e+00  7.300000e+01  1.072703e-05  6.829339e+01
# max    5.427665e+06  0.000000e+00  9.000000e+01  2.337394e-04  1.015534e+02
#
#               u_200         u_850         v_200         v_850           sst  \
# count  5.427666e+06  5.427666e+06  5.427666e+06  5.427666e+06  5.427666e+06
# mean   7.656760e+00 -2.693753e+00 -1.856880e+00  9.688508e-01  2.177395e+02
# ...

# %%
print(my_df.compare(other_df))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(pd.concat([my_df,other_df]).drop_duplicates(keep=False))
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, latitude, longitude, time, vo, r, u_200, u_850, v_200, v_850, sst, tcwv, tclw, tciw, shear]
# Index: []
